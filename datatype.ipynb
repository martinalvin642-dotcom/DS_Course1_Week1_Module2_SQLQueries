# %% [markdown]
# name, age, city
# Francis, 34, Nairobi
# Antonia, 21, Moshi
# Trevor, 23, Nakuru
# Steve, 32, Kisumu

# %%
import csv
with open("student.csv", "r") as file:
    stds = csv.reader(file)

    for std in stds:
        print(std)
# Out:
# ['name', ' age', ' city', '']
# ['Francis', '34', ' Nairobi', '']
# ['Antonia', ' 21', ' Moshi', '']
# ['Trevor', ' 23', ' Nakuru', '']
# ['Steve', ' 32', ' Kisumu']

# %%
with open('student.csv', 'r') as file:
    student_dict = csv.DictReader(file)
    for student in student_dict:
        print(int(student[' age']) +1)
# Out:
# 35
# 22
# 24
# 33

# %% [markdown]
# ## JSON (JavaScript Object Notation)
# its the most common data format used in websites, APIs, weeb scrapping, Unlike CSVs its often nested and not just rows and columns.
# iy resembles a python dictionary in that it stores data in key-value pairs.

# %%
import json

with open('student.json', 'r') as file:
    data = json.load(file)
    #print(data)
    print(json.dumps(data, indent=4))
# Out:
# {
#     "name": "Francis",
#     "age": 34,
#     "city": "Nairobi"
# }
